# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
x = np.linspace(-10, 10, 1000)

# %%
p = stats.skewnorm(1.25, loc=2, scale=1)
pp = stats.norm(2, 1)
plt.plot(x, p.pdf(x))
plt.plot(x, pp.pdf(x));
